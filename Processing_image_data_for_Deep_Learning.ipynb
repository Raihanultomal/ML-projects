# %% [markdown]
# **Topics:**
#
#
#
# *   Reading an image file and converting it to a numpy array
# *   Resizing an image
# *   RGB to Grayscale conversion

# %% [markdown]
# **Libraries that can be used for image processing:**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('cat_img.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1414, 2121, 3)

# %%
print(img)
# Out:
# [[[170 161 152]
#   [168 159 150]
#   [166 157 150]
#   ...
#   [198 200 195]
#   [196 198 193]
#   [198 200 195]]
#
#  [[159 150 141]
#   [159 150 141]
#   [161 152 145]
#   ...
#   [200 202 197]
#   [201 203 198]
#   [203 205 200]]
#
#  [[161 152 143]
#   [162 153 144]
#   [164 155 148]
#   ...
#   [202 204 199]
#   [204 206 201]
#   [201 203 198]]
#
#  ...
#
#  [[212 226 227]
#   [212 226 227]
#   [211 225 226]
#   ...
#   [178 194 194]
#   [177 193 193]
#   [178 194 194]]
#
#  [[212 226 227]
#   [212 226 227]
#   [211 225 226]
#   ...
#   [177 193 193]
#   [177 193 193]
#   [178 194 194]]
#
#  [[212 226 227]
#   [212 226 227]
#   [211 225 226]
#   ...
#   [177 193 193]
#   [179 195 195]
#   [178 194 194]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('cat_img.jpg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('cat_img.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('cat_img.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('cat_img.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (200, 200)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
# from google.colab.patches import cv2_imshow

image = cv2.imread('cat_img.jpg')

# %%
print(image)
# Out:
# [[[150 159 168]
#   [151 160 169]
#   [154 163 172]
#   ...
#   [199 204 203]
#   [199 204 203]
#   [199 204 203]]
#
#  [[149 158 167]
#   [151 160 169]
#   [154 163 172]
#   ...
#   [200 205 204]
#   [199 204 203]
#   [199 204 203]]
#
#  [[149 159 166]
#   [150 160 167]
#   [153 163 170]
#   ...
#   [200 205 204]
#   [200 205 204]
#   [199 204 203]]
#
#  ...
#
#  [[225 228 213]
#   [225 228 213]
#   [225 228 213]
#   ...
#   [179 177 166]
#   [177 173 162]
#   [175 171 160]]
#
#  [[225 228 213]
#   [224 227 212]
#   [224 227 212]
#   ...
#   [199 197 186]
#   [194 192 181]
#   [191 189 178]]
#
#  [[223 226 211]
#   [223 226 211]
#   [223 226 211]
#   ...
#   [202 200 189]
#   [196 194 183]
#   [191 189 178]]]

# %%
# displaying the image
# cv2_imshow(grayscale_image)

cv2.imwrite('gray_cat_img.jpg', grayscale_image)  # new file name gray_cat_img that converted gray image of original inage
# Out:
# True

# %%
from IPython.display import Image

# %%
Image(filename='gray_cat_img.jpg')
